# %%
# %run phugoid.py
# %matplotlib inline

# %%
#zt = 64, z = 16, and theta = 0
#C needs to be between 0 and 2/3 in order to be trochoidal
#When C = 0 we get a constant radius
plot_flight_path(64,16,0)
